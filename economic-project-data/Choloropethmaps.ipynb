# %%
import json
import numpy as np
import pandas as pd
import plotly.express as px
import plotly.io as pio
# pio.renderers.default = 'browser'

# %%
us_states = json.load(open("us-states.json", "r"))
us_states['features'][2]
# Out:
# {'type': 'Feature',
#  'id': 'AZ',
#  'properties': {'name': 'Arizona'},
#  'geometry': {'type': 'Polygon',
#   'coordinates': [[[-109.042503, 37.000263],
#     [-109.04798, 31.331629],
#     [-111.074448, 31.331629],
#     [-112.246513, 31.704061],
#     [-114.815198, 32.492741],
#     [-114.72209, 32.717295],
#     [-114.524921, 32.755634],
#     [-114.470151, 32.843265],
#     [-114.524921, 33.029481],
#     [-114.661844, 33.034958],
#     [-114.727567, 33.40739],
#     [-114.524921, 33.54979],
#     [-114.497536, 33.697668],
#     [-114.535874, 33.933176],
#     [-114.415382, 34.108438],
#     [-114.256551, 34.174162],
#     [-114.136058, 34.305608],
#     [-114.333228, 34.448009],
#     [-114.470151, 34.710902],
#     [-114.634459, 34.87521],
#     [-114.634459, 35.00118],
#     [-114.574213, 35.138103],
#     [-114.596121, 35.324319],
#     [-114.678275, 35.516012],
#     [-114.738521, 36.102045],
#     [-114.371566, 36.140383],
#     [-114.251074, 36.01989],
# ...

# %%
from urllib.request import urlopen
import json
with urlopen('https://raw.githubusercontent.com/plotly/datasets/master/geojson-counties-fips.json') as response:
    counties = json.load(response)

# import pandas as pd
# df = pd.read_csv("Master_DF.csv")
# df.head(100)

# %%
df['GeoName'].unique()
# Out:
# array(['United States', 'Alabama', 'Alaska', 'Arizona', 'Arkansas',
#        'California', 'Colorado', 'Connecticut', 'Delaware',
#        'District of Columbia', 'Florida', 'Georgia', 'Hawaii', 'Idaho',
#        'Illinois', 'Indiana', 'Iowa', 'Kansas', 'Kentucky', 'Louisiana',
#        'Maine', 'Maryland', 'Massachusetts', 'Michigan', 'Minnesota',
#        'Mississippi', 'Missouri', 'Montana', 'Nebraska', 'Nevada',
#        'New Hampshire', 'New Jersey', 'New Mexico', 'New York',
#        'North Carolina', 'North Dakota', 'Ohio', 'Oklahoma', 'Oregon',
#        'Pennsylvania', 'Rhode Island', 'South Carolina', 'South Dakota',
#        'Tennessee', 'Texas', 'Utah', 'Vermont', 'Virginia', 'Washington',
#        'West Virginia', 'Wisconsin', 'Wyoming', 'New England', 'Mideast',
#        'Great Lakes', 'Plains', 'Southeast', 'Southwest',
#        'Rocky Mountain', 'Far West'], dtype=object)

# %%
#making new dataframe 
df_national = df['GeoName'] == 'United States'
df_states = df[df['GeoName'].isin(['Alabama', 'Alaska', 'Arizona', 'Arkansas',
       'California', 'Colorado', 'Connecticut', 'Delaware',
       'District of Columbia', 'Florida', 'Georgia', 'Hawaii', 'Idaho',
       'Illinois', 'Indiana', 'Iowa', 'Kansas', 'Kentucky', 'Louisiana',
       'Maine', 'Maryland', 'Massachusetts', 'Michigan', 'Minnesota',
       'Mississippi', 'Missouri', 'Montana', 'Nebraska', 'Nevada',
       'New Hampshire', 'New Jersey', 'New Mexico', 'New York',
       'North Carolina', 'North Dakota', 'Ohio', 'Oklahoma', 'Oregon',
       'Pennsylvania', 'Rhode Island', 'South Carolina', 'South Dakota',
       'Tennessee', 'Texas', 'Utah', 'Vermont', 'Virginia', 'Washington',
       'West Virginia', 'Wisconsin', 'Wyoming'])]

# %%
# Out:
#             GeoName  Quarter  Year        Date  Real GDP  Personal Income  \
# 2292  West Virginia        3  2019  2019-09-30   72959.8          76438.4
# 2293  West Virginia        4  2019  2019-03-31   73761.6          76914.0
# 2294  West Virginia        1  2020  2020-03-31   71725.7          76634.8
# 2295  West Virginia        2  2020  2020-06-30   65547.3          87151.3
# 2296  West Virginia        3  2020  2020-09-30   70427.4          79065.3
# ...             ...      ...   ...         ...       ...              ...
# 2387        Wyoming        2  2020  2020-06-30   34125.7          37267.7
# 2388        Wyoming        3  2020  2020-09-30   36364.7          35407.2
# 2389        Wyoming        4  2020  2020-03-31   36477.2          35827.5
# 2390        Wyoming        1  2021  2021-03-31   36808.8          39704.7
# 2391        Wyoming        2  2021  2021-06-30   37014.4          37141.5
#
#       Population  Real GDP per Capita  Personal Income per Capita
# ...

# %%
#how to Make new df by splitting 
df1 = pd.read_csv("Master_DF.csv")
df1_nat = df1[df1['GeoName'] == 'United States']
df1_states = df1[df1['GeoName'].isin(['Alabama', 'Alaska', 'Arizona', 'Arkansas',
       'California', 'Colorado', 'Connecticut', 'Delaware',
       'District of Columbia', 'Florida', 'Georgia', 'Hawaii', 'Idaho',
       'Illinois', 'Indiana', 'Iowa', 'Kansas', 'Kentucky', 'Louisiana',
       'Maine', 'Maryland', 'Massachusetts', 'Michigan', 'Minnesota',
       'Mississippi', 'Missouri', 'Montana', 'Nebraska', 'Nevada',
       'New Hampshire', 'New Jersey', 'New Mexico', 'New York',
       'North Carolina', 'North Dakota', 'Ohio', 'Oklahoma', 'Oregon',
       'Pennsylvania', 'Rhode Island', 'South Carolina', 'South Dakota',
       'Tennessee', 'Texas', 'Utah', 'Vermont', 'Virginia', 'Washington',
       'West Virginia', 'Wisconsin', 'Wyoming'])]
df1_regions = df1[df1['GeoName'].isin(['Wyoming', 'New England', 'Mideast',
       'Great Lakes', 'Plains', 'Southeast', 'Southwest',
       'Rocky Mountain', 'Far West'])]
df1.head()

# df1_states.plot(kind='scatter', x= "Real GDP", y= "Personal Income", s=1)
# sns.regplot(x='Real GDP', y='Personal Income',data = df1_states, x_jitter=0.4)
df_1_states_recent = df1_states["Date"] == "2021-06-30"

# %%
df1_states_recent = df1_states[df1_states["Date"] == "2021-06-30"]

# %%
df1_states_recent.head()
# Out:
#         GeoName  Quarter  Year        Date   Real GDP  Personal Income  \
# 91      Alabama        2  2021  2021-06-30   203961.8         237403.1
# 137      Alaska        2  2021  2021-06-30    50251.6          47715.2
# 183     Arizona        2  2021  2021-06-30   331353.4         379521.8
# 229    Arkansas        2  2021  2021-06-30   120905.3         149122.2
# 275  California        2  2021  2021-06-30  2832619.1        2919391.2
#
#      Population  Real GDP per Capita  Personal Income per Capita
# 91      4932200             0.041353                    0.048133
# 137      728469             0.068982                    0.065501
# 183     7534248             0.043980                    0.050373
# 229     3038401             0.039792                    0.049079
# 275    39289961             0.072095                    0.074304

# %%
import plotly.express as px

fig = px.choropleth(df_1_states_recent, geojson=counties, locations='GeoName', color='Personal Income',
                           color_continuous_scale="Viridis",
                           range_color=(0, 300000),
                           scope="usa",
                           
                          )
fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})
fig.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-38-86c7be34b7a7> in <module>
#       1 import plotly.express as px
#       2
# ----> 3 fig = px.choropleth(df_1_states_recent, geojson=counties, locations='GeoName', color='Personal Income',
#       4                            color_continuous_scale="Viridis",
#       5                            range_color=(0, 300000),
#
# ...

# %%
df1.head()
# Out:
#          GeoName  Quarter  Year        Date    Real GDP  Personal Income  \
# 0  United States        1  2010  2010-03-31  15456059.0       12311038.1
# 1  United States        2  2010  2010-06-30  15605628.0       12537406.3
# 2  United States        3  2010  2010-09-30  15726282.0       12675765.0
# 3  United States        4  2010  2010-03-31  15807995.0       12821826.6
# 4  United States        1  2011  2011-03-31  15769911.0       13170613.6
#
#    Population  Real GDP per Capita  Personal Income per Capita
# 0   308468490             0.050106                    0.039910
# 1   309038072             0.050497                    0.040569
# 2   309659806             0.050786                    0.040934
# 3   310275835             0.050948                    0.041324
# 4   310785239             0.050742                    0.042379

# %%
# state_id_map={}
# for features in us_states['features']:
#     features["id"] = features["properties"]['name']
#     state_id_map[features["properties"]["name"]] = features["id"]
 
# df["id"] = df["index"].apply(lambda x: state_id_map[x])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-51-7b5a1eb027ed> in <module>
#       4     state_id_map[features["properties"]["name"]] = features["id"]
#       5
# ----> 6 df["id"] = df["index"].apply(lambda x: state_id_map[x])
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwds)
#    3846             else:
#    3847                 values = self.astype(object).values
# -> 3848                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    3849
#    3850         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-51-7b5a1eb027ed> in <lambda>(x)
#       4     state_id_map[features["properties"]["name"]] = features["id"]
#       5
# ----> 6 df["id"] = df["index"].apply(lambda x: state_id_map[x])
#
# ...

# %%
fig = px.choropleth(df_1_states_recent, geojson=us_states, locations='fips', color='unemp',
                           color_continuous_scale="Viridis",
                           range_color=(0, 12),
                           scope="usa"
                        
                          )
fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})
fig.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-9efa005f346b> in <module>
# ----> 1 fig = px.choropleth(df_1_states_recent, geojson=us_states, locations='fips', color='unemp',
#       2                            color_continuous_scale="Viridis",
#       3                            range_color=(0, 12),
#       4                            scope="usa"
#       5
#
# NameError: name 'us_states' is not defined
